# %% [markdown]
# ## **EDA**
#
# ## Kaggle Healthy Eating Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/healthy_eating_dataset.csv")  
df.head()
# Out:
#    meal_id      meal_name  cuisine meal_type diet_type  calories  protein_g  \
# 0        1      Kid Pasta   Indian     Lunch      Keto       737       52.4
# 1        2   Husband Rice  Mexican     Lunch     Paleo       182       74.7
# 2        3  Activity Rice   Indian     Snack     Paleo       881       52.9
# 3        4  Another Salad  Mexican     Snack      Keto       427       17.5
# 4        5     Quite Stew     Thai     Lunch     Vegan       210       51.6
#
#    carbs_g  fat_g  fiber_g  sugar_g  sodium_mg  cholesterol_mg  \
# 0     43.9   34.3     16.8     42.9       2079              91
# 1    144.4    0.1     22.3     38.6        423               7
# 2     97.3   18.8     20.0     37.5       2383             209
# 3     73.1    7.6      9.8     41.7        846             107
# 4    104.3   26.3     24.8     18.2       1460              42
#
#    serving_size_g cooking_method  prep_time_min  cook_time_min  rating  \
# ...

# %%
df.shape
#2000 rows, 20 columns
# Out:
# (2000, 20)

# %%
#drop the irrelevant columns
df = df.drop(columns=['meal_id', 'rating', 'is_healthy', 'image_url'], errors='ignore')

# %%
df.shape
# Out:
# (2000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   meal_name       2000 non-null   object
#  1   cuisine         2000 non-null   object
#  2   meal_type       2000 non-null   object
#  3   diet_type       2000 non-null   object
#  4   calories        2000 non-null   int64
#  5   protein_g       2000 non-null   float64
#  6   carbs_g         2000 non-null   float64
#  7   fat_g           2000 non-null   float64
#  8   fiber_g         2000 non-null   float64
#  9   sugar_g         2000 non-null   float64
#  10  sodium_mg       2000 non-null   int64
#  11  cholesterol_mg  2000 non-null   int64
#  12  serving_size_g  2000 non-null   int64
#  13  cooking_method  2000 non-null   object
#  14  prep_time_min   2000 non-null   int64
#  15  cook_time_min   2000 non-null   int64
# dtypes: float64(5), int64(6), object(5)
# ...

# %%
df.describe().round(1)
# Out:
#        calories  protein_g  carbs_g   fat_g  fiber_g  sugar_g  sodium_mg  \
# count    2000.0     2000.0   2000.0  2000.0   2000.0   2000.0     2000.0
# mean      650.1       42.9     75.9    30.1     15.2     24.6     1257.3
# std       315.4       22.0     42.7    17.6      8.8     14.5      709.6
# min       100.0        5.0      0.0     0.0      0.0      0.0       50.0
# 25%       372.0       23.6     39.2    14.8      7.6     12.0      647.5
# 50%       648.0       43.6     76.0    30.3     15.2     24.8     1273.0
# 75%       914.5       61.9    113.0    45.2     23.2     37.2     1854.5
# max      1200.0       79.9    150.0    60.0     30.0     50.0     2499.0
#
#        cholesterol_mg  serving_size_g  prep_time_min  cook_time_min
# count          2000.0          2000.0         2000.0         2000.0
# mean            150.5           302.6           33.4           61.5
# std              87.9           115.5           16.5           33.6
# ...

# %%
df.columns
# Out:
# Index(['meal_name', 'cuisine', 'meal_type', 'diet_type', 'calories',
#        'protein_g', 'carbs_g', 'fat_g', 'fiber_g', 'sugar_g', 'sodium_mg',
#        'cholesterol_mg', 'serving_size_g', 'cooking_method', 'prep_time_min',
#        'cook_time_min'],
#       dtype='object')

# %%
df['cuisine'].value_counts()
# Out:
# cuisine
# Indian           282
# Mediterranean    266
# American         261
# Mexican          251
# Chinese          245
# Thai             233
# Italian          232
# Japanese         230
# Name: count, dtype: int64

# %%
df['meal_type'].value_counts()
# Out:
# meal_type
# Lunch        513
# Breakfast    504
# Dinner       493
# Snack        490
# Name: count, dtype: int64

# %%
df['diet_type'].value_counts()
# Out:
# diet_type
# Balanced      352
# Vegan         345
# Low-Carb      338
# Vegetarian    324
# Keto          322
# Paleo         319
# Name: count, dtype: int64

# %%
df['cooking_method'].value_counts()
# Out:
# cooking_method
# Fried      315
# Boiled     306
# Roasted    295
# Baked      294
# Steamed    280
# Raw        267
# Grilled    243
# Name: count, dtype: int64

# %% [markdown]
# ## **EDA**
#
# ## Kaggle Nutrition Dataset ##

# %%
df1 = pd.read_csv("../data/raw/nutrition.csv")  
df1.head(4)
# Out:
#    Unnamed: 0            name serving_size  calories total_fat saturated_fat  \
# 0           0      Cornstarch        100 g       381      0.1g           NaN
# 1           1    Nuts, pecans        100 g       691       72g          6.2g
# 2           2   Eggplant, raw        100 g        25      0.2g           NaN
# 3           3  Teff, uncooked        100 g       367      2.4g          0.4g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
#
# ...

# %%
print("Shape:", df1.shape)
# Out:
# Shape: (8789, 77)

# %%
df1.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# saturated_fat    1590
# Unnamed: 0          0
# lysine              0
# tyrosine            0
# tryptophan          0
# dtype: int64

# %%
print(df1.columns)
# Out:
# Index(['Unnamed: 0', 'name', 'serving_size', 'calories', 'total_fat',
#        'saturated_fat', 'cholesterol', 'sodium', 'choline', 'folate',
#        'folic_acid', 'niacin', 'pantothenic_acid', 'riboflavin', 'thiamin',
#        'vitamin_a', 'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
print(df.columns)
# Out:
# Index(['meal_name', 'cuisine', 'meal_type', 'diet_type', 'calories',
#        'protein_g', 'carbs_g', 'fat_g', 'fiber_g', 'sugar_g', 'sodium_mg',
#        'cholesterol_mg', 'serving_size_g', 'cooking_method', 'prep_time_min',
#        'cook_time_min'],
#       dtype='object')

# %%
#drop the "unnamed: 0"
df1 = df1.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
df1.shape
# Out:
# (8789, 76)

# %%
#count of missing values
df1.isnull().sum().sort_values(ascending=False)
# Out:
# saturated_fat    1590
# name                0
# lysine              0
# tyrosine            0
# tryptophan          0
#                  ...
# vitamin_e           0
# vitamin_d           0
# vitamin_c           0
# vitamin_b6          0
# water               0
# Length: 76, dtype: int64

# %%
# Missing probably means zero saturated fat
df1['saturated_fat'] = df1['saturated_fat'].fillna(0)
#That's why I would rather fill with a zero rather than median
#df1['saturated_fat'] = df1['saturated_fat'].fillna(df1['saturated_fat'].median())

# %%
df1.isnull().sum().sort_values(ascending=False).head()
# Out:
# name          0
# lysine        0
# tyrosine      0
# tryptophan    0
# threonine     0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Saving df and df1 as csv files ##

# %%
# Save df1 to CSV
df1.to_csv("cleaned_nutrition.csv", index=False)

# Save df to CSV
df.to_csv("cleaned_healthy_meals.csv", index=False)

# %%
df3 = pd.read_csv("../data/raw/cleaned_nutrition.csv")  
df3.head(4)
# Out:
#              name serving_size  calories total_fat saturated_fat cholesterol  \
# 0      Cornstarch        100 g       381      0.1g             0           0
# 1    Nuts, pecans        100 g       691       72g          6.2g           0
# 2   Eggplant, raw        100 g        25      0.2g             0           0
# 3  Teff, uncooked        100 g       367      2.4g          0.4g           0
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
#
# ...

# %%
df4 = pd.read_csv("../data/raw/cleaned_healthy_meals.csv")  
df4.head(4)
# Out:
#        meal_name  cuisine meal_type diet_type  calories  protein_g  carbs_g  \
# 0      Kid Pasta   Indian     Lunch      Keto       737       52.4     43.9
# 1   Husband Rice  Mexican     Lunch     Paleo       182       74.7    144.4
# 2  Activity Rice   Indian     Snack     Paleo       881       52.9     97.3
# 3  Another Salad  Mexican     Snack      Keto       427       17.5     73.1
#
#    fat_g  fiber_g  sugar_g  sodium_mg  cholesterol_mg  serving_size_g  \
# 0   34.3     16.8     42.9       2079              91             206
# 1    0.1     22.3     38.6        423               7             317
# 2   18.8     20.0     37.5       2383             209             395
# 3    7.6      9.8     41.7        846             107             499
#
#   cooking_method  prep_time_min  cook_time_min
# 0        Grilled             47             56
# 1        Roasted             51             34
# 2         Boiled             58             29
# ...
