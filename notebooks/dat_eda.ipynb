# %% [markdown]
# ## EDA Recipe Dataset (over 2M) Food

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/recipes_data.csv')

# %%
df.shape
# Out:
# (2231142, 7)

# %%
df.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  Jewell Ball'S Chicken  ["1 small jar chipped beef, cut up", "4 boned ...
# 2            Creamy Corn  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3          Chicken Funny  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4   Reeses Cups(Candy)    ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   ingredients  object
#  2   directions   object
#  3   link         object
#  4   source       object
#  5   NER          object
#  6   site         object
# dtypes: object(7)
# memory usage: 119.2+ MB

# %%
df.columns.tolist()
# Out:
# ['title', 'ingredients', 'directions', 'link', 'source', 'NER', 'site']

# %%
df.sample(5)
# Out:
#                        title
# 1012718   Steamed Jelly Eggs  \
# 2196111     Espresso Granita
# 2073452           Pizza Stew
# 245803    Raisin Toffee Bars
# 1810632  Herbed Garden Salad
#
#                                                ingredients
# 1012718  ["3 eggs, beaten", "cold water, same volume of...  \
# 2196111  ["12 cup sugar", "2 tablespoons water", "6 cup...
# 2073452  ["6 ounces bacon canadian", "9 cups tomato sau...
# 245803   ["1 c. sifted flour", "1/2 tsp. salt", "1/2 c....
# 1810632  ["6 -8 cups mixed salad greens, such as Lolla ...
#
#                                                 directions
# 1012718  ["Mix the first five ingredients well.", "Pour...  \
# 2196111  ["Combine the sugar and water in a saucepan an...
# 2073452  ["Fry canadian bacon.", "Drain and cut away an...
# 245803   ["Sift flour and salt.", "Combine butter and s...
# 1810632  ["Place lettuce in a large bowl.", "Add basil,...
#
# ...

# %%
df.isnull().sum()
# Out:
# title          1
# ingredients    0
# directions     0
# link           0
# source         0
# NER            0
# site           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_recipes_sample = pd.read_csv('../data/recipes_data_sample.csv')
df_recipes_sample.head()
# Out:
#    Unnamed: 0                         title  \
# 0     2015528  Marinated Flank Steak Recipe
# 1     1608734           French Chicken Stew
# 2      778500                Glazed Carrots
# 3     1334975               Moms Pie Dough
# 4      116562      Pretzel Salad Or Dessert
#
#                                          ingredients  \
# 0  ["1 1/2 pound flank steak", "1/2 c. finely min...
# 1  ["1 tablespoon rosemary", "1 teaspoon thyme", ...
# 2  ["3 to 4 carrots", "1 1/2 Tbsp. butter", "1/3 ...
# 3  ["4.5 Cups Flour", "1.5 Tsp Salt", "Pinch Baki...
# 4  ["2 c. crushed small thin pretzels (sticks)", ...
#
#                                           directions  \
# 0  ["Remove tenderloin from steak.", "Score meat....
# 1  ["combine all ingredients in slow cooker (6 qu...
# 2  ["Cook 3 to 4 carrots; cut crosswise in 1-inch...
# 3  ["Mix all dry ingredients in a bowl.", "", "Ad...
# 4  ["Mix and press in baking pan, approximately 1...
#
# ...

# %%
df_recipes_sample = df_recipes_sample.drop(columns=['Unnamed: 0','link', 'source', 'site'])

# %%
df_recipes_sample.head()
# Out:
#                           title  \
# 0  Marinated Flank Steak Recipe
# 1           French Chicken Stew
# 2                Glazed Carrots
# 3               Moms Pie Dough
# 4      Pretzel Salad Or Dessert
#
#                                          ingredients  \
# 0  ["1 1/2 pound flank steak", "1/2 c. finely min...
# 1  ["1 tablespoon rosemary", "1 teaspoon thyme", ...
# 2  ["3 to 4 carrots", "1 1/2 Tbsp. butter", "1/3 ...
# 3  ["4.5 Cups Flour", "1.5 Tsp Salt", "Pinch Baki...
# 4  ["2 c. crushed small thin pretzels (sticks)", ...
#
#                                           directions  \
# 0  ["Remove tenderloin from steak.", "Score meat....
# 1  ["combine all ingredients in slow cooker (6 qu...
# 2  ["Cook 3 to 4 carrots; cut crosswise in 1-inch...
# 3  ["Mix all dry ingredients in a bowl.", "", "Ad...
# 4  ["Mix and press in baking pan, approximately 1...
#
#                                                  NER
# 0  ["soy sauce", "green onions", "salad oil", "se...
# ...

# %%
df_recipes_sample.to_csv('../data/cleaned_recipes_data_sample.csv')

# %%
df2 = pd.read_csv('../data/recipes.csv')

# %%
df2.shape
# Out:
# (1090, 15)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1090 non-null   int64
#  1   recipe_name   1090 non-null   object
#  2   prep_time     1039 non-null   object
#  3   cook_time     782 non-null    object
#  4   total_time    1045 non-null   object
#  5   servings      1090 non-null   int64
#  6   yield         879 non-null    object
#  7   ingredients   1090 non-null   object
#  8   directions    1090 non-null   object
#  9   rating        1090 non-null   float64
#  10  url           1090 non-null   object
#  11  cuisine_path  1090 non-null   object
#  12  nutrition     1090 non-null   object
#  13  timing        1090 non-null   object
#  14  img_src       1090 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 127.9+ KB

# %%
df2.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'recipe_name',
#  'prep_time',
#  'cook_time',
#  'total_time',
#  'servings',
#  'yield',
#  'ingredients',
#  'directions',
#  'rating',
#  'url',
#  'cuisine_path',
#  'nutrition',
#  'timing',
#  'img_src']

# %%
df2 = df2.drop(columns=['Unnamed: 0','rating','url','img_src'])

# %%
df2.to_csv('../data/cleaned_recipes.csv')

# %%
df2.head(5)
# Out:
#                    recipe_name prep_time cook_time     total_time  servings  \
# 0     Apple-Cranberry Crostada       NaN       NaN            NaN         8
# 1    Apple Pie by Grandma Ople   30 mins     1 hrs  1 hrs 30 mins         8
# 2  Sarah's Homemade Applesauce   10 mins   15 mins        25 mins         4
# 3                  Apple Crisp   30 mins   45 mins  1 hrs 15 mins        12
# 4            Apple Pie Filling   20 mins   20 mins  2 hrs 40 mins        40
#
#                yield                                        ingredients  \
# 0  6 to 8 - servings  3 tablespoons butter, 2 pounds Granny Smith ap...
# 1       1 9-inch pie  8 small Granny Smith apples, or as needed, ½ c...
# 2                NaN  4  apples - peeled, cored and chopped, ¾ cup w...
# 3    1 9x13-inch pan  10 cups all-purpose apples, peeled, cored and ...
# 4      5 9-inch pies  18 cups thinly sliced apples, 3 tablespoons le...
#
#                                           directions  \
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0        0
# recipe_name       0
# prep_time        51
# cook_time       308
# total_time       45
# servings          0
# yield           211
# ingredients       0
# directions        0
# rating            0
# url               0
# cuisine_path      0
# nutrition         0
# timing            0
# img_src           0
# dtype: int64
