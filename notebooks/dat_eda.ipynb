# %% [markdown]
# ## EDA Recipe Dataset (over 2M) Food

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/recipes_data.csv')

# %%
df.shape
# Out:
# (2231142, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   ingredients  object
#  2   directions   object
#  3   link         object
#  4   source       object
#  5   NER          object
#  6   site         object
# dtypes: object(7)
# memory usage: 119.2+ MB

# %%
df.columns.tolist()
# Out:
# ['title', 'ingredients', 'directions', 'link', 'source', 'NER', 'site']

# %%
df.sample(5)
# Out:
#                        title
# 1012718   Steamed Jelly Eggs  \
# 2196111     Espresso Granita
# 2073452           Pizza Stew
# 245803    Raisin Toffee Bars
# 1810632  Herbed Garden Salad
#
#                                                ingredients
# 1012718  ["3 eggs, beaten", "cold water, same volume of...  \
# 2196111  ["12 cup sugar", "2 tablespoons water", "6 cup...
# 2073452  ["6 ounces bacon canadian", "9 cups tomato sau...
# 245803   ["1 c. sifted flour", "1/2 tsp. salt", "1/2 c....
# 1810632  ["6 -8 cups mixed salad greens, such as Lolla ...
#
#                                                 directions
# 1012718  ["Mix the first five ingredients well.", "Pour...  \
# 2196111  ["Combine the sugar and water in a saucepan an...
# 2073452  ["Fry canadian bacon.", "Drain and cut away an...
# 245803   ["Sift flour and salt.", "Combine butter and s...
# 1810632  ["Place lettuce in a large bowl.", "Add basil,...
#
# ...

# %%
df.isnull().sum()
# Out:
# title          1
# ingredients    0
# directions     0
# link           0
# source         0
# NER            0
# site           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df2 = pd.read_csv('../data/recipes.csv')

# %%
df2.shape
# Out:
# (1090, 15)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1090 non-null   int64
#  1   recipe_name   1090 non-null   object
#  2   prep_time     1039 non-null   object
#  3   cook_time     782 non-null    object
#  4   total_time    1045 non-null   object
#  5   servings      1090 non-null   int64
#  6   yield         879 non-null    object
#  7   ingredients   1090 non-null   object
#  8   directions    1090 non-null   object
#  9   rating        1090 non-null   float64
#  10  url           1090 non-null   object
#  11  cuisine_path  1090 non-null   object
#  12  nutrition     1090 non-null   object
#  13  timing        1090 non-null   object
#  14  img_src       1090 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 127.9+ KB

# %%
df2.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'recipe_name',
#  'prep_time',
#  'cook_time',
#  'total_time',
#  'servings',
#  'yield',
#  'ingredients',
#  'directions',
#  'rating',
#  'url',
#  'cuisine_path',
#  'nutrition',
#  'timing',
#  'img_src']

# %%
df2.sample(5)
# Out:
#      Unnamed: 0                          recipe_name prep_time cook_time
# 877         877                      Apricot Cookies       NaN       NaN  \
# 276         276                Watermelon Margaritas   10 mins       NaN
# 631         631  Southern-Style Baked Banana Pudding   30 mins   15 mins
# 289         289        Watermelon Fire and Ice Salsa   15 mins       NaN
# 655         655              A Drama Queen's Pavlova   30 mins   50 mins
#
#         total_time  servings          yield
# 877            NaN        24        4 dozen  \
# 276        10 mins         4   4 margaritas
# 631        45 mins         8  1 10-inch pan
# 289        15 mins        32         4 cups
# 655  1 hrs 20 mins        12    12 servings
#
#                                            ingredients
# 877  1 cup butter, 1 cup white sugar, 3 cups all-pu...  \
# 276  2 cups cubed seeded watermelon, 2 cups crushed...
# 631                                       4 large eggs
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0        0
# recipe_name       0
# prep_time        51
# cook_time       308
# total_time       45
# servings          0
# yield           211
# ingredients       0
# directions        0
# rating            0
# url               0
# cuisine_path      0
# nutrition         0
# timing            0
# img_src           0
# dtype: int64
